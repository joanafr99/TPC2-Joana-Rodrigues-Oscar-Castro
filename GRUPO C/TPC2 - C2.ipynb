# %% [markdown]
# # Questão C2. A
#
# ## -Gapminder_animation
#
#
# ### Get the data (csv file is hosted on the web)
#
# * Usamos a variável "url" para importar o ficheiro "gapminderData.csv" (url = 'https://python-graph-gallery.com/wp-content/uploads/gapminderData.csv'), para buscar os dados.
#
# * Usamos o **data = pd.read_csv(url)** para ler o ficheiro csv e por fim, utilizar a função data.head() para mostrar, por definição, as primeiras 5 linhas da tabela.
#
#
# ### And I need to transform my categorical column (continent) in a numerical value group1->1, group2->2...
#
# * Ler a informação data da coluna dos continentes através do **pd.Categorical(data["continent"])**
#
# * Ao igualar **data["continent]** a **pd.Categorical(data["continent"])**, fazemos a contagem de "continent" diferentes, separando esta informação em apenas 5 valores.
#
#
# ### %matplotlib notebook
#
# * Usar o **"%matplotlib notebook"** para chamar a biblioteca de software "matplotlib"
#
# * Definir um gráfico para cada data, com base na função (i), ou seja, **for i in data.year.unique()**
#
# * Definir a largura dos eixos em relação ao plot, com 680 dpi de comprimento e 480 dpi de largura através de **"fig, ax = plt.subplots(figsize=(680/my_dpi, 480/my_dpi), dpi=my_dpi)"**.
#
# * Colocar um tempo para apesentar os anos com base na função i com o **tmp=data[ data.year == i ]**
#
# * Usando **plt.scatter(tmp['lifeExp'], tmp['gdpPercap'] , s=tmp['pop']/200000 , c=tmp['continent'].cat.codes, cmap="Accent", alpha=0.6, edgecolors="white", linewidth=2)**, escolhemos os dados a serem importados em relação aos eixos para as bolhas atribuindo-lhes as suas carateristicas.
#
# * Usando o **plt.yscale('log')** , os valores do eixo y passam a ser baseados no logaritimo
#
# * Usando o **plt.xlabel("Life Expectancy")** e **plt.ylabel("GDP per Capita")**  atribui-mos uma legenda ao eixos e o **plt.title("Year: "+str(i) )** para atribuir um titulo para cada plot
#
# * Usando o **plt.ylim(0,100000)** e **plt.xlim(30, 90)** limita-mos os eixos num certo intervalo
#
# * Usar o **filename='Gapminder_step'+str(i)+'.png'** para dar nome ao ficheiro e guarda-lo em png, depois guardamos com uma qualidade de dpi de 96 utilizando o **plt.savefig(filename, dpi=96)** e por ultimo, utlizamos o **plt.gca()** de maneira a que os eixos do plot aparecem no ficheiro
#
#
#
#
#
#
# ## -Gapminder_animation-FuncAnimation_PLOT_SEM-legend
#
#
# ### Get the data (csv file is hosted on the web)
#
# * Usamos a variável "url" para importar o ficheiro "gapminderData.csv" (url = 'https://python-graph-gallery.com/wp-content/uploads/gapminderData.csv'), para buscar os dados.
#
# * Usamos o **data = pd.read_csv(url)** para ler o ficheiro csv e por fim, utilizar a função data.head() para mostrar, por definição, as primeiras 5 linhas da tabela.
#
#
# ### And I need to transform my categorical column (continent) in a numerical value group1->1, group2->2...
#
# * Ler a informação data da coluna dos continentes através do **pd.Categorical(data["continent"])**
#
# * Ao igualar **data["continent]** a **pd.Categorical(data["continent"])**, fazemos a contagem de "continent" diferentes, separando esta informação em apenas 5 valores.
#
# * Usar o **anos=data.year.unique()** para criar um variável que conte os anos únicos.
#
#
#
# ### %matplotlib notebook
#
# * Usar o **"%matplotlib notebook"** para chamar a biblioteca de software "matplotlib"
#
# * Definir a largura dos eixos em relação ao plot, com 680 dpi de comprimento e 480 dpi de largura através de **"fig, ax = plt.subplots(figsize=(680/my_dpi, 480/my_dpi), dpi=my_dpi)"**.
#
#
# * Usando o **plt.yscale('log')** , os valores do eixo y passam a ser baseados no logaritimo
#
# * Usando o **plt.xlabel("Life Expectancy")** e **plt.ylabel("GDP per Capita")**  atribui-mos uma legenda ao eixos e o **plt.title("Year: "+str(i) )** para atribuir um titulo para cada plot
#
# * Usando o **plt.ylim(0,100000)** e **plt.xlim(30, 90)** limita-mos os eixos num certo intervalo
#
#
#
# * Usando:
#     o **def animate(i)**, definimos a animação a ser mostrada.
#     o **plt.title("Year: "+str(anos[i])**, serve para colocar um titulo que corresponde ao ano durante a animação,tendo em conta a função
#     o **tmp=data[ data.year == anos[i] ]**, serve para apresentar os anos durante a animação, tendo em conta a função
#     o **scut=plt.scatter(tmp['lifeExp'], tmp['gdpPercap'] , s=tmp['pop']/200000 , c=tmp['continent'].cat.codes, cmap="Accent", alpha=0.6, edgecolors="white", linewidth=2)**, serve para atribuir carateirsitcas as "bolhas", ou seja, os dados importados.
#
# * Usando o **ani = animation.FuncAnimation(fig, animate, frames=len(anos), interval=200, blit=False, repeat=False)**, definimos os frames que seram mostrados na animação, o intervalo entre as animações, para não permitir que copie o conteudo de uma superficie para outra e por fim disbilitar a repetição.
#
#
# * Usar o **plt.show()** para mostrar o plot.

# %% [markdown]
# # Questão C2. B
# * As cores de cada bolha representa o continente, o tamanho das bolhas varia consoante a quantidade da população e aa suas expressuras e tonalidades alteradas através do **linewidth=2** e **alpha=0.6**
#
# * No "gapminder_animation-FuncAnimation_PLOT_SEM-legend" temos uma animação contínua, onde os frames são apresentados através do **interval=200**, para terem um espaço de 200milisegundos.

# %% [markdown]
# # Questão C2.C
#
# ## Legendas.
#
#
# * Usamos o **plt.plot** para acrescentar linhas num novo gráfico, de maneira a criar uma legenda unica para todos os gráficos seguintes.
# * Dentro do **plt.plo**
#         *acresentamos os handles,
#         *o nome através da label,
#         *o marker de modo a aparecer um simbolo de uma bola na legenda,
#         *a cor w, para colorir a linha que atravessava o simbolo da bolha de branco, de maneira a que a linha não apareça,
#         *o markersize para alterar a cor do simbolo,
#         *o markersize para alterar o tamanho do simbolo.
#
# * Usamos o **plt.legend** para colocar a caixa da legenda, o titulo da legenda e a sua localização, e o tamanho das letras.
